# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Souza-Santos/InteligenciaArtificialUFPE/blob/main/DatasetDiabete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.22.2.post1'

# %%
diabetes = x, y = datasets.load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
# Correlação
for i in range(0, 10):
  plt.figure(figsize=(8, 6))
  plt.title(f"gráfico {i + 1}")
  plt.scatter(x[:, i], y)

# %%
# Correlação de Cada Curva:
print("============= CORRELAÇÃO ============== ")
for i in range(0, 10):
  print(f"Gráfico {i}: {round(np.corrcoef(x[:, i], y)[0][1], 2)}")
# Out:
# ============= CORRELAÇÃO ==============
# Gráfico 0: 0.19
# Gráfico 1: 0.04
# Gráfico 2: 0.59
# Gráfico 3: 0.44
# Gráfico 4: 0.21
# Gráfico 5: 0.17
# Gráfico 6: -0.39
# Gráfico 7: 0.43
# Gráfico 8: 0.57
# Gráfico 9: 0.38

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
import pandas as pd

# %%
diabetes_df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)

# %%
diabetes_df
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018118  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046879  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044528 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
diabetes_df.corr()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# age  1.000000  0.173737  0.185085  ...  0.203841  0.270777  0.301731
# sex  0.173737  1.000000  0.088161  ...  0.332115  0.149918  0.208133
# bmi  0.185085  0.088161  1.000000  ...  0.413807  0.446159  0.388680
# bp   0.335427  0.241013  0.395415  ...  0.257653  0.393478  0.390429
# s1   0.260061  0.035277  0.249777  ...  0.542207  0.515501  0.325717
# s2   0.219243  0.142637  0.261170  ...  0.659817  0.318353  0.290600
# s3  -0.075181 -0.379090 -0.366811  ... -0.738493 -0.398577 -0.273697
# s4   0.203841  0.332115  0.413807  ...  1.000000  0.617857  0.417212
# s5   0.270777  0.149918  0.446159  ...  0.617857  1.000000  0.464670
# s6   0.301731  0.208133  0.388680  ...  0.417212  0.464670  1.000000
#
# [10 rows x 10 columns]

# %%
diabetes_df['y'] = diabetes.target
diabetes_df.head(2)
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6      y
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019908 -0.017646  151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068330 -0.092204   75.0
#
# [2 rows x 11 columns]

# %%
sns.pairplot(diabetes_df[['age', 'y']])
sns.pairplot(diabetes_df[['sex', 'y']])
sns.pairplot(diabetes_df[['bmi', 'y']])
sns.pairplot(diabetes_df[['bp', 'y']])
sns.pairplot(diabetes_df[['s1', 'y']])
sns.pairplot(diabetes_df[['s2', 'y']])
sns.pairplot(diabetes_df[['s3', 'y']])
sns.pairplot(diabetes_df[['s4', 'y']])
sns.pairplot(diabetes_df[['s5', 'y']])
sns.pairplot(diabetes_df[['s6', 'y']])

# %%
from sklearn.model_selection import train_test_split

# %%
X = diabetes_df.drop('y', 1)
X
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018118  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046879  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044528 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
Y = diabetes_df['y']
Y.head(5)
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: y, dtype: float64

# %%
X_train, X_test, Y_train, Y_teste = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
ln = LinearRegression()
ln.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = ln.predict(X_test)
pred
# Out:
# array([ 58.10669977, 152.37066656,  74.94997386, 195.82292951,
#        254.00105047, 114.15389689, 251.29775628,  99.36648532,
#        153.99029803, 133.13129886, 196.54690275, 240.49276363,
#        242.78853746, 117.32121037,  89.53428698, 106.7653967 ,
#        193.94858316,  69.88209953, 172.24230878, 192.19133742,
#        160.68363606,  75.4653934 , 138.02731879,  83.34801409,
#        231.89615161, 226.99955426, 105.05518624,  71.16346476,
#        182.54113621, 173.8415988 , 216.30007128, 107.72130611,
#         81.29461568, 139.13358791, 160.60350839, 145.37254912,
#        226.96154222,  81.68776498, 209.82855939,  89.94671856,
#        151.32741642, 296.50312155,  94.05266169, 162.52930269,
#        185.50745556, 106.37411242,  99.81640459,  83.27178676,
#        124.47420949, 131.75167154, 108.01579018, 246.19176102,
#        165.71895355,  65.82920403, 123.90327603, 179.21438588,
#        185.26432401, 207.70910623, 232.26706768, 182.12920891,
# ...

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-30]
diabetes_X_test = diabetes_X[-30:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-30]
diabetes_y_test = diabetes_y[-30:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [941.43097333]
# Mean squared error: 3035.06
# Coefficient of determination: 0.41

# %%
from sklearn import metrics
MAF = metrics.mean_absolute_error(Y_teste, pred)
# MAF

MSE = np.sqrt(metrics.mean_squared_error(Y_teste, pred))
MSE
# Out:
# 57.651386189813046
